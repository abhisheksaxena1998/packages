# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksaxena1998/packages/blob/master/annotate_hate_Threats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install hatesonar
# Out:
# ...
#      |████████████████████████████████| 1.1MB 2.7MB/s
# ...

# %%
from hatesonar import Sonar
sonar = Sonar()
s=sonar.ping(text="At least I'm not a nigger")
a=s['classes'][0]['confidence']
b=s['classes'][1]['confidence']
c=s['classes'][2]['confidence']
maxi=max(a,b,c)
if a==maxi:
    cos=s['classes'][0]['class_name']
elif b==maxi:
    cos=s['classes'][1]['class_name']
else:
    cos=s['classes'][2]['class_name']
cos
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
import pandas as pd
import numpy as np
import csv
df=pd.read_csv("Nicky Morgan.csv",encoding="latin1")
df = df.dropna(axis=0, subset=['text'])

df=df.sample(frac=0.4,random_state=42)
len(df)
# Out:
# 2501

# %%
CoS=[]
for i in df['text']:
    sonar = Sonar()
    s=sonar.ping(text=i)
    a=s['classes'][0]['confidence']
    b=s['classes'][1]['confidence']
    c=s['classes'][2]['confidence']
    maxi=max(a,b,c)
    if a==maxi:
        cos=s['classes'][0]['class_name']
    elif b==maxi:
        cos=s['classes'][1]['class_name']
    else:
        cos=s['classes'][2]['class_name']
    print (cos)    
    CoS.append(cos)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.19.1 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# neither
# offensive_language
# ...

# %%
df['classofspeech']=CoS
df.to_csv("input_threat_NickyMorgan.csv")
df
# Out:
#       Unnamed: 0  ...       classofspeech
# 1703        1703  ...             neither
# 5449        5449  ...             neither
# 5058        5058  ...             neither
# 1149        1149  ...             neither
# 432          432  ...             neither
# ...          ...  ...                 ...
# 1113        1113  ...             neither
# 3340        3340  ...             neither
# 1552        1552  ...             neither
# 5337        5337  ...  offensive_language
# 4668        4668  ...             neither
#
# [2501 rows x 23 columns]

# %%
df1=pd.read_csv("input_threat_NickyMorgan.csv",encoding="latin1")
df1
# Out:
#       Unnamed: 0  ...       classofspeech
# 0           1703  ...             neither
# 1           5449  ...             neither
# 2           5058  ...             neither
# 3           1149  ...             neither
# 4            432  ...             neither
# ...          ...  ...                 ...
# 2496        1113  ...             neither
# 2497        3340  ...             neither
# 2498        1552  ...             neither
# 2499        5337  ...  offensive_language
# 2500        4668  ...             neither
#
# [2501 rows x 24 columns]

# %%
g=df1.groupby('classofspeech',sort=True).count()

# %%
g
# Out:
#                     Unnamed: 0  Unnamed: 0.1  ...  parent_tweet_id  reply_to_users
# classofspeech                                 ...
# neither                   2317          2317  ...              905            2317
# offensive_language         184           184  ...               89             184
#
# [2 rows x 23 columns]

# %%
df1['month']=df1['timestamp'].apply(lambda x :x[5:7])
df1.to_csv("final Nicky Morgan.csv")
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...       classofspeech month
# 0           1703          1703  ...             neither    06
# 1           5449          5449  ...             neither    09
# 2           5058          5058  ...             neither    07
# 3           1149          1149  ...             neither    05
# 4            432           432  ...             neither    08
# ...          ...           ...  ...                 ...   ...
# 2496        1113          1113  ...             neither    05
# 2497        3340          3340  ...             neither    10
# 2498        1552          1552  ...             neither    05
# 2499        5337          5337  ...  offensive_language    09
# 2500        4668          4668  ...             neither    10
#
# [2501 rows x 25 columns]

# %%
d1=pd.read_csv("final amber rudd.csv",encoding="latin1")
d1
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...       classofspeech month
# 0              0           735  ...             neither     6
# 1              1          1261  ...             neither     5
# 2              2          7184  ...  offensive_language     8
# 3              3          9864  ...             neither     4
# 4              4          7226  ...  offensive_language     8
# ...          ...           ...  ...                 ...   ...
# 1000        1000          8708  ...             neither     8
# 1001        1001          1726  ...             neither     6
# 1002        1002          4812  ...             neither     6
# 1003        1003          1149  ...             neither     5
# 1004        1004          5385  ...             neither     4
#
# [1005 rows x 26 columns]

# %%
b1z=d1.groupby('month',sort=True)['classofspeech'].count()
b1z
# Out:
# month
# 4     32
# 5     10
# 6     48
# 7      6
# 8     56
# 9    109
# Name: classofspeech, dtype: int64

# %%
import pandas as pd
import numpy as np
d1=pd.read_csv("Mark1ann.csv",encoding="latin1")
d1
# Out:
#      Unnamed: 0  ...  classofspeech
# 0             0  ...        neither
# 1             1  ...        neither
# 2             2  ...        neither
# 3             3  ...        neither
# 4             4  ...        neither
# ..          ...  ...            ...
# 697         697  ...        neither
# 698         698  ...        neither
# 699         699  ...        neither
# 700         700  ...        neither
# 701         701  ...        neither
#
# [702 rows x 24 columns]
