# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksaxena1998/packages/blob/master/annotate_stance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests

import matplotlib.pyplot as plt

df=pd.read_csv('stephentwigg.csv')
df
# Out:
#            date  ...                                              tweet
# 0    2019-07-30  ...  Thanks to everyone who contributed evidence to...
# 1    2019-07-28  ...  Thanks for the Tweet. Email me with details an...
# 2    2019-07-27  ...  Fantastic atmosphere at @LCRPride today includ...
# 3    2019-07-26  ...  Looking forward to @PrideInLpool march tomorro...
# 4    2019-07-26  ...  Very informative visit today to the @MerseyPol...
# ..          ...  ...                                                ...
# 145  2019-02-12  ...  Thanks Cathy. Yes. Can you email me key points...
# 146  2019-02-06  ...  There is a basic injustice in the local govern...
# 147  2019-02-06  ...  My article today with Andrew Mitchell reaffirm...
# 148  2019-02-01  ...                                     Well done Eva!
# 149  2019-02-01  ...  The outstanding @eprnschool, @EllergreenNS & @...
#
# [150 rows x 3 columns]

# %%
url="http://104.248.174.180/api/stance/brexit_tweets/"

stance=[]
for i in df['tweet']:
    def post_json(url,json_data):

      res= requests.post(url,json=json_data)
      #print (res.json())
      jsonobj=res.json()
      stance.append(jsonobj[0]['Stance'])
      print (jsonobj[0]['Stance'])
    post_json(url,{"Tweets":[i]})
# Out:
# leave
# no sentiment
# no sentiment
# irrelevant
# no sentiment
# no sentiment
# irrelevant
# leave
# irrelevant
# irrelevant
# irrelevant
# irrelevant
# stay
# irrelevant
# irrelevant
# leave
# leave
# no sentiment
# leave
# stay
# stay
# stay
# leave
# leave
# leave
# no sentiment
# leave
# stay
# no sentiment
# stay
# leave
# irrelevant
# no sentiment
# no sentiment
# leave
# no sentiment
# no sentiment
# stay
# stay
# leave
# no sentiment
# stay
# stay
# leave
# stay
# irrelevant
# irrelevant
# no sentiment
# no sentiment
# irrelevant
# no sentiment
# stay
# leave
# stay
# irrelevant
# leave
# stay
# irrelevant
# stay
# leave
# leave
# leave
# leave
# no sentiment
# leave
# leave
# leave
# leave
# no sentiment
# leave
# stay
# no sentiment
# no sentiment
# leave
# leave
# no sentiment
# irrelevant
# stay
# leave
# stay
# leave
# leave
# leave
# irrelevant
# stay
# no sentiment
# leave
# leave
# stay
# stay
# irrelevant
# stay
# leave
# leave
# irrelevant
# leave
# irrelevant
# leave
# stay
# stay
# no sentiment
# leave
# leave
# leave
# leave
# leave
# leave
# no sentiment
# leave
# leave
# leave
# leave
# leave
# leave
# no sentiment
# no sentiment
# no sentiment
# no sentiment
# leave
# leave
# leave
# irrelevant
# irrelevant
# no sentiment
# no sentiment
# no sentiment
# no sentiment
# irrelevant
# leave
# irrelevant
# no sentiment
# leave
# leave
# irrelevant
# no sentiment
# no sentiment
# irrelevant
# irrelevant
# leave
# no sentiment
# leave
# no sentiment
# leave
# no sentiment
# no sentiment
# no sentiment
# leave
# irrelevant
# leave
# irrelevant

# %%
df['date']=df['date'].apply(lambda x :x[5:7])
df['stance']=stance
df.to_csv('stephentwigg_stance.csv')
df=pd.read_csv('stephentwigg_stance.csv')
df
# Out:
#      Unnamed: 0  ...        stance
# 0             0  ...         leave
# 1             1  ...  no sentiment
# 2             2  ...  no sentiment
# 3             3  ...    irrelevant
# 4             4  ...  no sentiment
# ..          ...  ...           ...
# 145         145  ...  no sentiment
# 146         146  ...         leave
# 147         147  ...    irrelevant
# 148         148  ...         leave
# 149         149  ...    irrelevant
#
# [150 rows x 5 columns]
