# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksaxena1998/packages/blob/master/absa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m=pd.read_csv('amazon_reviews.csv')
df_m=df_m.sample(frac=0.1)
df_m
# Out:
#      web-scraper-order  ...                                          next-href
# 2968  1575554098-12030  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 9225  1575557404-16484  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 8730  1575558559-19475  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 3609  1575555120-14746  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 273     1575539556-423  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# ...                ...  ...                                                ...
# 4294  1575555314-15370  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 5668  1575554441-12942  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 7431  1575558592-19581  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 2326  1575555272-15231  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 2024  1575553970-11725  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
#
# [958 rows x 9 columns]

# %%
import requests
x="Good riddance. #sexismpic.twitter.com/wv3taIFwm0. I don't normally do these & I'm avoiding my usual buddies."
import requests
response=requests.get(f'http://104.248.174.180/api/absa/?query={x}')
#print(response.json())
jsonobj=response.json()
if response.status_code==200:
  print (jsonobj['Frequent Features'][0])
# Out:
# good riddance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m=pd.read_csv('amazon_reviews.csv')

df_m
# Out:
#      web-scraper-order  ...                                          next-href
# 0       1575539665-696  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 1       1575539598-532  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 2       1575539507-289  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 3       1575539673-712  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 4       1575539685-740  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# ...                ...  ...                                                ...
# 9571  1575557390-16439  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 9572  1575557238-15940  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 9573  1575558457-19146  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 9574  1575558311-18817  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 9575  1575558269-18680  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
#
# [9576 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m=pd.read_csv('amazon_reviews.csv')
df_m=df_m.sample(frac=0.1)
df_m
# Out:
#      web-scraper-order  ...                                          next-href
# 3981  1575555404-15694  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 8717  1575558236-18587  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 8577  1575558311-18808  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 3288  1575553729-11037  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 7350  1575557841-17440  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# ...                ...  ...                                                ...
# 1116  1575555120-14738  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 1873  1575555129-14771  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 4271  1575554070-11976  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 4240  1575555322-15400  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
# 7706  1575558308-18804  ...  https://www.amazon.in/JBL-Portable-Wireless-Bl...
#
# [958 rows x 9 columns]

# %%
import requests
x="Good riddance. #sexismpic.twitter.com/wv3taIFwm0. I don't normally do these & I'm avoiding my usual buddies."
import requests
response=requests.get(f'http://104.248.174.180/api/absa/?query={x}')
#print(response.json())
jsonobj=response.json()
if response.status_code==200:
  print (jsonobj['Frequent Features'])
# Out:
# ['good riddance']

# %%
df_m['content']
# Out:
# 3981     I didn't expect so much from such a tiny speaker
# 8717    Can't work with laptop...may I know how to ope...
# 8577    But I received a defective product.\nNone can ...
# 3288    Worst product.. Bluetooth not working, alws sh...
# 7350    it has been one month now the Bluetooth button...
#                               ...
# 1116    Everyone wants to buy them after they saw how ...
# 1873    Very good build quality. Awesome quality sound...
# 4271    A small powerhouse only thing is the battery l...
# 4240    Chota pack bada dhamaka...awesome sound and go...
# 7706    Hey all...Got this speaker today only and also...
# Name: content, Length: 958, dtype: object

# %%
import requests
x=df_m['content']
emotion=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/api/absa/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    #print (jsonobj['number_negative_words'])
    emotion.append(jsonobj['Frequent Features'])
    print (jsonobj['Frequent Features'])
# Out:
# ['tiny speaker']
# ['ca', "n't work", 'laptop ...']
# ['defective product', 'amazing', 'excellent bass', 'full volume', 'upper model', 'simply']
# ['worst', 'bluetooth']
# ['bluetooth']
# ['great fan', 'worthful product']
# ['plastic box package', 'felt']
# []
# ['protable speaker']
# []
# ['portable speakers', 'sound', 'issue i', 'blue tooth switch', 'long time', 'pc']
# ['review online', 'certain frequencies..', 'good product']
# ['awesome', 'clear sound quality', 'okayish', 'max volume', 'bluetooth connectivity', 'build', 'overall']
# ['bluetooth', 'portable speaker', 'sound quality']
# ['product quality', 'good alternatives']
# ['compitability', 'returned']
# ['nice blootooth speaker', 'battery']
# ['mic']
# ['batter product']
# ['great speaker', 'go music', 'perfect battery backup', 'premium look']
# ['dirty product.battery life', 'short nad', "n't purchase"]
# ['3w bluetooth speaker', "market ..it 's bluetooth connectivity", 'stone', "'s connectivity", 'fault piece', 'sound quality', 'sound clarity', 'great .weight', 'jbl']
# ['sound']
# ['sound', 'good ...']
# ['bluetooth', 'connection support', 'good distance', 'battery', 'sound']
# ['price point', 'option s']
# ['speakr', 'good bt i', 'speaker charger..']
# ['descent']
# ['small', 'portable speaker', 'awesome bass']
# ['really', 'connects', 'phone laptop', 'bluetooth', 'sec.good quality']
# ['jbl', 'online market place', 'harman', 'serial number', 'thanks amazon']
# ['bluetooth speakers .high output', 'ma sony hifi speakers', 'quality .vocals', 'little thing .worth buyng']
# ['awesome', 'good bass']
# ['ossum', 'sound quality', 'battery life', 'good ...', 'aur', 'bhaai bahut achha hai chhote packet', 'bada dhamaka hai']
# ['good quality 👎👎👎👎']
# []
# ['sound', 'good n', 'nice bass', 'battery', 'long time', 'sound ...', 'non dust product ...', 'noticeable problems']
# ['’ ve']
# ['pink', 'black', 'jbl']
# ['love', 'sound quality', '’ s', 'bluetooth']
# ['truely', 'aweaome product..', 'clear voice', 'steardy', 'body n finishing..', 'nice n', 'put.. batt life', 'long.. getz charge', 'leas tym..', 'bingo jbl', 'amazon', 'quick']
# ['sound']
# ['fabulous', 'short outings', 'battery life', 'happy results']
# ['bluetooth', 'mi', 'price bt', 'voice quality', 'superb ..', 'perfect.. bt jbl', 'bahut bekaar hai.. badaaaaaaaaaaaa wala bekar ... ... ..', 'mi bt', 'k samne bhus hai yai ...', 'cheap', 'voice toh usse v jyda']
# ['small device', 'onboard radio']
# ['sound', 'good ..but', "..it 's", 'amazon', "customer..there 's"]
# ['large rooms', 'ideal', 'hostel room', 'bass', 'cosidering', 'somebody', 'jbl', 'pocket']
# ['bluetooth', 'i order']
# ['capacity battery']
# ['chota', 'packet bada dhamaka', 'superb', 'speaker.. couldn ’ t', 'small speaker', 'love']
# []
# ['good..repent buying']
# ['philips bluetooth speaker', 'different brand', 'basic requirement', 'small size', 'good descent output', 'basic requirements']
# ['eventually']
# ['road trip', 'truly', 'wonderful experience', 'continuous play', 'pocket size speaker']
# ['be.bass missing.with bluetooth cuts']
# ['nice', 'overall feature..i', 'clarity speakers']
# ['worst.did']
# ['product i', 'small rooms cars etc']
# ['sound']
# []
# ['ofcrs', 'comments ...', 'compliments ...', 'handy product', 'luv wid', 'nice color n', 'sound clarity', 'perfect ...']
# ['sound quality', 'jbl', 'guys', 'boat', 'philips', 'lesser price']
# []
# []
# ['sd', 'card slot']
# ['5watt speaker']
# ['jbl', 'bluetooth', 'speaker system', 'success plz look']
# ['average', 'sound quality', '1.30-2.00 hours']
# ['battery', 'medium vol level', 'sound quality', 'good product']
# ['perfect', 'sound quality']
# ['sound']
# ['usb charger', 'usb cable', 'product didnt', 'gud product']
# ['where.sound quality', 'expected.best value', 'money budget product']
# ['sound', 'jbl brand', "n't hesitate", 'thank']
# ['good ratings', "ca n't", 'audiophile grade', 'tiny portable speaker', 'frequency range', 'jbl', 'end making', 'poor boom box', 'primary purpose', 'portable speakerphone', 'noise cancelation', 'conference calls', 'jbl=junk', 'loud']
# ['radio option', 'usb/sd card options']
# ['bluetooth device', 'worked', 'pls', '... product return']
# ['loved', 'compact size', 'long wait i', 'sound quality', 'jbl', 'great work', 'overall', 'warranty card', 'australia', 'idk']
# ['average']
# ['good quality']
# ['bluetooth', 'good speaker']
# ['prompt']
# ['size n']
# ['great wireless bluetooth speakers', 'performance', 'xiaomi speakers']
# ['bass', 'upto expectation', 'range 2k', 'boat stone']
# ['month bluetooth nt working..', 'response ...', 'bakwaas', '... mat kharido ... services center v nahi hai ...', 'ghata']
# ['pros', 'clear', 'cons', 'little', 'bass', 'shudders', 'slight bass freqs', 'voice']
# ['impressive sound ouput', 'keeping']
# ['upto mark jbl']
# ['buy', 'happy', 'sound', 'nice']
# ['music guy', 'differentiate base', 'jbl speaker i']
# ['small', 'great sound quality', 'need', 'usb', 'standard android cable']
# ['good product']
# ["pro 's", 'pro', 'light weight', 'small size', 'pause n play button', 'previous button']
# ['sound']
# ['quality sound quantity', 'owing', 'sold']
# ['jbl', 'cusomer care']
# ["'s ok", 'sound quality']
# ['awesome', 'sound quality', 'clear fills', 'handy', 'worth']
# ['wonder ful product', 'jbl', 'big quality', 'sound speaker.it', 'worth']
# ['good portable speaker', 'loud n', 'looks', 'supurb n', 'bright colour']
# []
# ['well', 'bit high', 'price range', 'good product']
# ['purchased', 'compact speaker', 'great impact', 'ideal', 'high volume']
# ['ultimate', 'decision u']
# ['nice jbl', 'sound', 'thanks amazon']
# ['sound', 'bluetooth']
# ['gift pack', 'normal parcel']
# ['reviewing', 'rating', 'material', 'sound', 'battery']
# ['poor sound quality ...']
# ['got', 'mom coz']
# ['sound']
# ['good ultra']
# ['usb port']
# []
# ['small device', 'small parties', 'amazon', 'regards prachi']
# ['material quality', 'bass', 'mid', 'treble', 'overall']
# []
# ['full bakwas', '90s radio', 'never', 'item road side speaker', 'lost', 'jbl']
# ['amazon', 'excellent', 'jbl', 'loudest volume', 'feet size', 'big brothers', 'bass', 'old melodies', 'indian classical etc', 'size bass', 'sound', 'awesome', 'high bass', '’ s connectivity', '’ s', 'memory slot', 'price range', 'close']
# ['sound quality', 'good ...', 'replacement ...']
# ["ca n't", 'sound quality', 'fatafati ...', 'important part', "'s bass", 'osadharon or🔥', 'word ...', 'youtubers', 'money ...', 'rubber body ...']
# []
# ['small box', 'battery', 'clarity']
# ['bluetooths', 'jbl go', 'otherwise jbl', 'pure sounds output']
# ['bluetooth', 'non usage', 'everytime', 'battery', 'sound']
# ['bad sounds', 'large spekar', 'rs.2100']
# ['otherwise', 'fr speaker']
# ["'s ok ..."]
# ['tiny', 'size speaker', 'good coverage', 'frequency ...', 'laptop ...', 'wo']
# ['product ...', 'good price', 'good sound ... ..', 'jbl']
# ['battery issue', 'jbl', 'service centre', 'bangalore', 'old battery', 'rs']
# ['dr', 'hu y']
# ['sound', 'size']
# ['sound']
# ['good sound quality', 'powerful bass', 'connects', 'bluetooth', 'apple devices']
# ['jbl', 'previously', 'philips bt-50', 'lesser price', "'s appearance", 'sound quality']
# ['nice product']
# []
# ['great product', 'simple']
# ['good speaker', 'jbl', 'material', 'sound quality', 'battery life', 'red colour', 'battery', 'philips speaker', 'thank']
# ['amazing..as', 'yeah', "bass ai n't good", 'high volumes', 'i.e', 'good speaker', 'connects', 'amazing battery', 'days n till']
# ['nice..small packet', 'big sound..', 'room..and others too..but good', 'awesome too..after', 'jbl']
# ['dont buy this', 'waste of money', 'initially', 'sound', 'mobiles']
# []
# ['money ... ... ...', 'small product']
# ['quality', 'expected..poor sound..']
# ['oh', 'sound bomb', 'durable design', 'fantastic', 'sound quality', 'great battery life', 'music box', 'op6', 'infact', 'jbl endurance dive']
# ['boom product', 'time purchase']
# ['sounds']
# ['battery life']
# ['guys', 'amazing product', 'fabulous speaker', 'bluetooth', 'jbl', 'aux cable']
# ['usb', 'external usb device']
# ['amazon']
# ['month usage outdoor', 'sound quality', 'disturbing blub blub']
# ['base tha boat stone200']
# ['sound']
# ['yes.its']
# ['amazon', 'perfect', 'room filling', 'good voice clarity']
# ['u need', 'sound quality', 'home theater']
# ['got', 'faulty product']
# ['sound', 'awesome ... ... .jbl', 'ur phone']
# ['bluetooth', 'troubles eith', 'devices mine', 'samsung galaxy', 'j7max', 'otherwise']
# ['amazing', 'jbl', 'easy', 'sound', 'small speaker']
# ['handy', 'sounds']
# ['good nut']
# ['awesome product', 'sound', 'build', 'bettery', 'small room']
# ['saying.. chota bomb bada dhamaka..', 'sound output..', 'good.. bass', 'good ...', 'battery too..']
# ['ok']
# ['bought', 'diwali', "amazon 's return window", 'really', 'innocent people']
# []
# ['wifi stops']
# ['sound quality']
# ['jitna', 'naam suna wesa kuchh bhi nahi h kewal chhota sa yahi', 'sound koi khas nahi']
# ['sound', 'high level']
# ['memory slot']
# ['small device', 'inch x', 'high bass', 'rms', 'home theatre', 'philips', 'logitech system', 'fenda', 'sound output', 'price point']
# ['jbl', 'great product', 'battery', 'whole day', 'fyi', 'data card port', 'fm']
# []
# ['sound']
# ['defective', 'refunded']
# ['product', 'thikthak hain', 'mahina ke', 'bluetooth', 'nahi ho raha hain', 'please']
# ['bluetooth']
# []
# ['sound quality']
# ['diwali sale', 'perfect condition', 'sound']
# ['mast', 'storng battery backup', 'easily', 'kar sakte hai', 'outdoor party']
# ['sound', 'frustrating']
# ['jbl', 'nice product']
# ['faulty']
# ['good music', 'portable speaker', 'clear']
# ['good product']
# ['music ohh', 'battery life', 'small thing']
# ['lot', 'noise', 'month ...']
# ['sound', 'sufficient max volume', 'battery life']
# ['please do not buy', 'neither amazon nor jbl is providing warranty for this product', 'pretty sure this product is refurbished', 'jbl bluntly told me that they do not cover warranty on products sold on amazon', 'this product has been giving me so many problems', 'it will work for few months then you will have issues']
# ['small room']
# ['jbl', 'amazing', 'price range', 'normal room', 'good clarity', 'nice bass', 'easy']
# ['worst', '... product', 'open market']
# ['love', 'easy', 'fits', 'ur purse..']
# []
# []
# []
# ['price category', 'poor battery quality']
# ['amazing', 'sound quality', 'complaints whatsoever']
# ['bluetooth']
# []
# ['poor', 'sound quality', 'movie', 'maximum volume', 'end version']
# ['sound quality', 'rich bass']
# []
# ['good quality']
# ['sound', 'continuesly', 'battery life']
# ['average quality product.sound quality ok']
# ['sound', 'mark ...', 'big disappointment ...']
# ['months battery life', 'period ...', 'jbl', 'raw material']
# ['superb']
# []
# ['adapter', 'otherwise', 'quality product']
# ['excellent', 'great quality', 'small room']
# ['great piece', "'s core"]
# ['x-mini']
# ['sound till date', 'battery backup lows', 'yup rust', 'overall', "wo n't disappoint"]
# ['unexpected', 'sound quality', 'tiny size.budget', 'takes']
# ['mac', 'conference calls']
# ['worst', 'sound quality']
# []
# ['great product', 'jbl']
# ['compact', 'courier services', 'amazon', 'assigned', 'courier guys numbers', 'delivery guy']
# ['good thing']
# ['good product', 'nice microphone', 'cool stylish', 'lightweight .the']
# ['sound', 'good n', 'nice bass', 'battery', 'long time', 'sound ...', 'non dust product ...', 'noticeable problems']
# []
# ['mobile phone']
# ['frills usage']
# ['have bought jbl bluetooth speaker but piece is defective and', 'replaced it', 'but another piece is also not good', 'voice is cracking when volume is full']
# ['great product', 'connectivity issues', 'clear', 'sound quality']
# ['absolutely', 'product', 'working', 'speaker phone', 'minimum', 'maximum']
# ['small speaker', 'exceeded', 'looks', 'battery', 'sleek']
# ['amazing', 'good sound quality', 'sound stays', 'loud volume', 'high pitch', 'light weight', 'good battery life', 'battery life']
# ['thank']
# ['jbl', 'superb', 'amazing', 'power backup']
# ['nice product', 'music lovers', 'connectivity', 'bluetooth']
# ['external jack']
# ['jbl flip..', 'sound quality']
# ['great product ...', 'sound quality', "lovely 'dabba"]
# ['amazing', 'runs', 'highly', 'festival sale', 'inr', 'dunno', 'current rate', 'current value']
# []
# ['battery', 'sound quality']
# ['good battery life', 'audio']
# ['jbl']
# ['really', 'amazing product', 'value', 'recieved', 'standard prime delivery', 'packaging', 'good n', 'short data cable', 'standard phone charger']
# ['worth', 'sound quality']
# ['please', 'attention', 'picture.so 1st']
# ['amazing device', 'favourite music']
# ['bought', 'september', 'quality', 'amazon', 'product quality', 'brokers offering services', 'sound', 'amazon advertise', 'amazon choice', '’ t']
# ['bad product']
# ['battery', 'great value']
# ['sound quality', 'full volume', 'bluetooth', 'music stops', 'media player', 'aux', 'smooth ...']
# ['sound', 'usb cable']
# ['product', 'good response', 'frequency spectrum', 'satisfied']
# []
# []
# ['great product']
# ['amazon', 'defective products', 'doesnt work properly..']
# ['product price range', 'battery', 'full volume', 'minor issue', 'search', 'jbl', 'youtube']
# ['jbl', 'red colour', 'weeks battery', 'warranty period']
# ['sound', 'hence']
# ['bass', 'sound quality']
# []
# ['lot time', 'wont reconnect automatically..', 'jbo']
# []
# ['sound', 'good ... .recmnd']
# ['music ohh', 'battery life', 'small thing']
# ["ca n't"]
# ['moment i', 'quality', 'bluetooth', 'shape etc etc', 'battery performance', 'superb product.. thanks jbl']
# ['nice', 'portable speaker', 'sound quality']
# []
# ['phone speaker']
# ['cudos amazon.. got']
# ['chotta packet bada damaka', "big speakers ca n't", 'value']
# ['year ...', "'s music quality", 'battery life', 'meditation ...', 'perfect', 'jbl']
# ["ca n't", 'conference calls']
# ['liked']
# ['bluetooth', 'connection problem occurs']
# ['great things', 'small package', 'completely', 'sound quality']
# ['product', 'quality', 'bluetooth speaker']
# ['good product']
# ['excellent product.very', 'clear sound.i', 'logitech x50', 'i dont']
# ['good experience', 'good sound quality', 'good battery', 'worth']
# ['unhappy', 'delivery time.. rest']
# []
# ['compact speaker', 'small room size']
# ['nt']
# ['bluetooth']
# ['gifted', 'family members', 'couple', 'foamy members', 'mother use', 'excellent touch', 'sound', "n't distort", 'high volume']
# []
# ['received', 'long time', 'good experience', 'worth buying']
# ['amazing']
# ['good sound quality ...', 'nice']
# ['good decent sound quality overall']
# ['microphone']
# ['ordered']
# ['month ... m', 'return past']
# ['boat']
# ['bluetooth', 'package seal', 'cello tape', 'hence', 'awesome']
# ['ok']
# ['sound quality', 'different laptops/mobile', 'pair everytime']
# ['months ...', 'nice', 'sound quality ...', 'good battery life ...', 'overall', 'good product ...']
# ['awesome', 'listening', 'fm transmitter', 'thanks', 'speed delivery']
# ['thump effect', 'good ... volumes', 'noise cancellation', '... lets', 'time ...', 'review ..good speaker']
# ['battery']
# []
# ['excellent']
# ['decent product', 'sound quality', 'jbl']
# ['wosrt', 'product ...']
# ['portable speaker', 'amazing sound quality', 'bluetooth connectivity', 'worth']
# []
# ['good sound quality..']
# []
# ['didn disappoint']
# ['jbl', 'great quality speaker', 'conference calls', 'returned']
# ['jbl', 'brand name', 'sound quality', 'size']
# ['seller', 'dec']
# ['looking', 'sound quality', 'sound clarity', 'boat']
# ['excellent']
# ['excellent', 'perfect', 'sound quality', 'flashy budget', 'bluetooth', 'jbl', 'minor nitpick', 'overall']
# ['good product', 'looks']
# ['waste', 'month ...']
# ["'s horrible.whithin 24days", 'service centre', 'customer care number']
# ['amazing', "ca n't", 'small package']
# ['bluetooth', 'good investment']
# ['sound quality ...', "bass ... i 've", '... boat', 'jbl', 'town ... guess ppl dont']
# ['got', 'week 😥😥 plz', 'thing jbl']
# ['speaker ’ colour', '’ s size', 'open setting']
# ['good product', 'batter life needs']
# ['value']
# ['jbl']
# ['nice wireless speaker', 'fair price', 'packet bada dhamaka', 'dad']
# ['sooo good', 'thought', 'price']
# ['august', 'waste piece', 'jbl']
# ["money 's worth"]
# ['speakers bluetooth connectivity']
# ['got', 'normal delivery option', 'packaging', 'voice clarity', 'control switches', "'s kind"]
# ['fake prices']
# ['bluetooth', 'bass', 'carrying']
# ['worth']
# ['excellent bluthooth speaker', 'small', 'excellent', 'sound clarity']
# []
# []
# ['okey']
# ['excellent', 'buying', 'wireless speaker', 'amazon', 'good range', 'money purchase']
# ['worst', 'usb', 'memorycard']
# ['jbl', 'red colour', 'weeks battery', 'warranty period']
# ['quick', 'instruction']
# ['product stopped working in', 'months time.it', 'amazon', 'jbl', 'buy', 'basically', 'keeping', 'paper weight.thanks', 'inferior product', 'brand name.speaks volumes', 'brand equity', 'thanks amazon', 'such products']
# ['awesome', 'grt', 'small size', 'ur pocket', 'one plus', "u 'll", 'full volume wid ur handsets..', 'dat', 'dis thing']
# ['ordered', 'waste']
# ['good device']
# ['good suffienct', 'room ... quality', 'decent doesnot', 'range ... ... battery life', 'good ... ... overall', 'product ... .if u r', 'price range']
# ['auto']
# ['jbl', 'e-commerce sites']
# ['ok ...']
# ['good sound quality', 'usb cable', 'quality']
# []
# ['jbl', 'product stands', 'unique sound quality', "friend 's birthday"]
# ["'s superb", 'sound quality']
# []
# []
# ['sound', 'bluetooth', 'worthwhile purchase']
# ['great product', '’ t', 'little rocker']
# ['engej plz']
# ['mitre high approximately.and']
# ['good speaker', 'bass', 'sound clarity', 'sound', 'mid volume', 'small room battery life', 'entire week']
# ['used', "ca n't comment", 'battery life']
# []
# ['1500/- idilum nalla speaker kittanilla nalla battery backup und outdore use cheythal', 'sound kittilla roomil use cheythal nalla', 'sound aanu bass oru padu illenkilum mosham illatha bass und']
# ['sound']
# ['pros', 'cons', 'hangs']
# []
# ['poor performance']
# ['open alrdy']
# ['please', 'jbl']
# ['total play time']
# ['bad experience']
# []
# ['damn good', 'dj', 'dhamaka', 'battery back-up', 'fits', 'your pocket', 'purchase wont empty your pockets', 'wireless connectivity', 'quality', 'black', 'expectations', 'lack', 'cheers']
# ['portable bluetooth speaker', 'jbl', 'sound', 'bass', 'bluetooth']
# ['excellent', 'in-house usage', 'large rooms', 'party halls', 'small room usage']
# ['nice']
# ["wo n't power", 'noise problems', 'durable quality product', 'price range', 'good faith', 'jbl']
# ['good product']
# ['bad quality audio']
# ['speaker ...', 'sound quality', 'overall']
# ['awesome product', 'worth', 'boat stone', '5t phone']
# ['drawback i', 'good sound quality', 'bluetooth', 'speaker phone', 'usb port', 'overall', 'excellent product']
# ['ok', 'problems', "ca n't", 'usb', 'otherwise']
# ['bought', 'great sound quality', 'nice product', 'hope']
# ['product', 'led', 'bluetooth', 'no sound']
# ['sound', 'small', 'suggest', 'music lover', 'low price ... ...']
# ['bluetooth', 'sound quality']
# ['usb', 'orange', 'odd colours']
# ['top', 'quality product', 'jbl', 'cheap speakers', 'good quality', 'great service', 'small rooms']
# ['jbl', 'intense dialogue', 'dramatic scene']
# ['bluetooth', 'range.. quality product', 'jbl..noise', 'facility..crystal clarity music..easy', 'street night parties..good battery']
# []
# ['sound']
# ['tareble', 'mark']
# ['sound quality', 'sound limit', 'basic thing', 'return time limit']
# ['sound quality', 'boat stone', 'jus', 'brand name']
# ['build']
# ['darshan', 'chota lakin kaj bada']
# ['heard']
# ['absolutely', 'amazing product']
# ['sound', 'bed', 'battery']
# ['sound quality']
# ['good product']
# ['nice', 'is.nice bass.we', 'big woofers speaker', 'bluetooth']
# ['small packages', 'battery life']
# ['year battery', 'good ...']
# ['sound']
# ['disappointing', 'bass quality', 'portable speaker', 'small audio block']
# ['amazing', 'copartable means', 'gym', 'outdoor', 'near pool']
# ['awsome awsome awsome', 'price', 'build quality', 'sound quality', 'portable audio standards', 'bass']
# ['dislike']
# ['jbl', 'brand.sound quality', 'product', "ca n't", 'overall', 'good product']
# ['bought', 'january', 'hours str8', "ca n't", 'device switches', 'battery drains', 'sound quality', 'sound buttons', 'aux', 'high hopes']
# ["'m bit confuse", 'ok', 'wan na', 'sound quality', 'jbl', 'jbl flip', "wo n't", 'sound output', "'s reason", '15-16w output', 'bass', "'s y", 'costs 6-7k', 'whole house', "'m music lover"]
# ['battery backup', 'everytime', 'i disconnect']
# ['awesome', 'sound quality', 'product ...', 'price ...']
# ['good sound quality']
# ['got', 'rs', 'car smith123', 'sale', '% cashback', 'keep', 'working']
# ['soft', 'happy']
# ['material', 'battery', 'daily use', 'car etc', 'diwali', 'bank discount', 'cashkaro rewards']
# ['sound', '’ s', 'bluetooth', 'overall', 'decent speakers']
# []
# ['high expectations', 'high volume']
# ['use ...', 'i use', 'i wan na return']
# ['strongly recommended']
# ['sound']
# ['ok product']
# ['nice', 'sound quality', 'small room']
# ['good product']
# ['price', 'good product i', 'easy', 'battery life', 'good ... ..i fact', 'big junbo speakers ... ..i fel', 'wht average', 'battery', 'wht i', 'full volume.which', 'easy cary']
# ['bluetooth', 'various websites..']
# ['good product..']
# ['usb', 'aux', 'box weew']
# []
# ['number indicator.when', 'red light', 'power button', 'red light indicator']
# ['good sound quality']
# ['very nice very good sound quality']
# []
# []
# ['excellent', 'voice clarity', 'evening relaxation hours', 'pleasant', 'private space']
# []
# ['portable boom', 'good bass..battery lasts long..great']
# ['worst']
# ['battery', 'cant use', 'good purchase', 'sound']
# ['awesome', 'dont', 'bluetooth', 'speakers ... .they']
# ['good product', 'price range..']
# ['otherwise', 'sound distortion', 'high volume', 'good bluetooth capability', 'high quality', 'top notch finish', 'jbl', 'looks', 'damn good']
# ['dont']
# ['waste', 'boat rugby', 'small box']
# ['sound quality']
# ['sound', '1st product']
# ['audio performance', 'selection buttons', 'visible particularity', 'dark hours', 'contrast color']
# ['good product', 'bluetooth']
# ['great sound quality', 'personal', 'quiet room', 'battery', 'good amount']
# ['service center', 'jbl']
# ['jbl', 'good product', 'sound', 'battery', 'easy', 'bluetooth']
# ['inches x', 'accoustic performace', 'negligible base', 'non existent', 'tonal quality', 'esp female vocals', 'iphone s', 'tiny speakers', 'vocal clarity', 'sound balance', 'shame', 'speaker bears', 'jbl', 'brand name', 'own risk']
# ['battery', 'cant use', 'good purchase', 'sound']
# ['average product..']
# []
# ['ok']
# ['good product']
# ['nice', 'sound quality', 'small', 'genuine product', 'thank', 'cloudtail', 'amazon']
# ['bluetooth']
# ['4months till date', 'amazon', 'batterylife', 'sound quality', 'value']
# ['battery backup']
# ['money product..', 'issues ...', 'great sound quality', 'battery lasts', 'long ...']
# ['unexpected', 'small size ...', 'size']
# ['red light']
# ['sound']
# ['sound quality']
# ['sound quality', 'long time']
# ['bluetooths', 'jbl go', 'otherwise jbl', 'pure sounds output']
# ['sound', "'s price range", 'travel distances']
# ['wonderful', 'mini speaker', 'heavy bass', 'price tag', 'little devil']
# ['small']
# ['sound', 'otherwise', 'nice product']
# ['bad product delivery exerience']
# ['fan', 'sounds quality', 'never', 'disappointed.. battery backup', 'good too..', 'hours average']
# ['quality product']
# ['good value']
# ['november jbl', 'speaker disturbed..']
# ['sound']
# ['product']
# []
# ['sound quality', 'boat', 'speaker i', 'overall i']
# ['failed', 'mi', 'bluetooth speaker']
# ['speaker went dead in just', 'days', 'do not buy this piece of rubbish', 'you will lose your money', 'rotten speaker sold by jbl to fool their customers']
# ['default product', 'i dont']
# ['ordered', 'different color']
# ['battery', 'pros', 'load', 'crisp upto', '% volume', '1. lacks bass punch']
# ['worth money ...', 'sound scatters']
# ['sound echo']
# ['product', 'good quality', 'sound package', 'time price', 'rupees only.. dont', 'it.. dont']
# ['boat']
# ['reviewing', 'daily usage', 'oh boy', 'music needs', 'excellent', 'perfect bass', 'audio quality', 'great bluetooth speakers', "wo n't"]
# []
# ['guys', 'input jack', 'output jack ie', 'hats']
# ['definitely']
# ['deffective', 'button']
# ['r u', 'return option ...', 'small ... i']
# ['pathetic speaker', 'never', 'weak product']
# ['sound', 'portability wise good', 'strap button', 'personal feedback', 'else']
# []
# []
# ['good product.sound quality']
# []
# []
# []
# ['sound', 'jbl', 'expectations', 'high volume', 'car stereo', 'worthy']
# ['27th march', 'bluetooth', 'june']
# ['nice', 'good sound quality.. battery back-up']
# ['overall']
# ['product details', 'windows']
# ["ca n't", 'samsung', "'s music", 'minutes stops']
# ['available online', 'affordable price..', 'great sound quality', 'easy bluetooth', 'thanks']
# ['awesome', 'excellent product', 'portable device']
# ['dislike']
# ['price range', 'good product']
# []
# ['sound']
# ['awesome']
# ['fake']
# ['superb']
# ['less', 'killer look', 'nice range', 'sound ... crystal', 'jbl service centre', 'rajendra place', 'new delhi']
# ['voice/speech clarity', 'songs', 'battery']
# ['... bass level', 'interesting ...']
# ['sound', "'s size"]
# ['supreb product', 'great thankful', 'amazon', 'thank']
# ['blue tooth']
# ['sounds', 'quality medium']
# ['superb', 'sound', 'quality minimizes', 'high volume', 'small room', 'sound quality', 'battery backup']
# ['happy', 'thanks']
# ['month afterwards', "n't work"]
# []
# []
# ['rough', 'tough product', 'great service', 'sound']
# ['good item']
# ['amazing speaker', "n't matter", 'good audio output', 'bass output']
# ['good sound quality', 'bass punch']
# ['superb']
# ['sound']
# ['jbl', 'audio jack', 'audio jack cable ...']
# []
# ['loud']
# []
# ['boat stone', 'jbl go', 'simply', 'boat', 'small house parties', "wo n't", 'enormous audio', 'tiny box', 'pros', 'trusted brand', 'jbl', 'harman', 'nuff', 'super-handy', 'carry', 'pocket service', 'availability', 'service centers', '/ email', 'battery backup', 'continuous playback', 'full volume', 'medium volume', 'bass', 'treble', 'beats', 'voice', 'durability', 'na', 'build quality', 'rock', 'cons', 'update', 'aug', 'battery']
# ['bad product ... ..']
# ['returned']
# ['deffective', 'button']
# ['jbl go', 'portable wireless speaker quality', 'sound', "sweet.it 's size", 'thanks amezon', 'such type']
# []
# ['courier services']
# ['jbl', 'please']
# ['hello', 'hi', 'ravi potghan', 'purchase order', 'jbl', 'bluetooth']
# ['nov', 'jbl', 'atleast ...', 'hugely disappointed..']
# ['’ s', 'amazing product', 'sound quality']
# ['product delivers']
# ['product image', 'amazon', 'actual product', 'never', 'jbl', 'future buyers']
# ['super bakvass sabko', 'mamu', 'banabna bhandh karo']
# ['great product', 'big room', 'great connectivity level', 'bluetooth range']
# ['extremely', 'amazon', 'defective product', '’ s', 'letter “ b ”', 'jbl', 'long time', 'negative ratings', 'defective piece']
# ['jbl']
# ['order today.but', 'm mot', 'item.so plz return item']
# ['sound', 'loud', 'free sound.can']
# []
# ['case u r', 'yes u', 'rs']
# ["product 's quality"]
# []
# ['unbelievable piece', 'smaller']
# ['product']
# ['nice product', 'wats speakares ...', 'sound']
# ['flash sale', 'audio', 'deep base output', 'small form factor']
# ['amazing', 'small package ..']
# ['huge device', 'i expected.sound charity', 'all that loud.but', 'cheap budget speaker', 'jbl.customers', 'harman', 'kindly request amazon to show the picture of the speaker small.but in other ways it', 'the best speaker']
# ['sound quality']
# ['till', 'product', 'sound']
# ['laptop volume', 'return period']
# []
# ['bad quality audio']
# ['good product', 'nice', 'sound quality', 'loudness']
# ['aux facility', 'bucks stereo mp3 player i', 'sound', 'call', 'itunes-iphone combination']
# ['battery']
# ['sound batry 6hours']
# ['weird problem', 'particular device', 'bluetooth', 'office meeting calls', 'weird noise', 'diwali', 'new device']
# ['loud']
# ['good voice amd', 'adequate bass', 'good product']
# ['superb', 'good sound quality', 'maximum volume', 'battery', 'great ... single charge', 'full day 12hrs', 'single press', 'long press']
# []
# ['charing', 'long time']
# ['poor bass']
# ['jbl speaker']
# ['worst']
# []
# ['sound']
# []
# ['music sounds bland', 'entry level speaker', 'cheap chinese speakers', 'worth ₹1800']
# []
# ['good product', 'decent']
# ['excellent', 'hours ...', 'good clear concise output']
# ['jbl', 'blutooth speaker', 'bill n paper', 'outer ploy']
# ['sound']
# ['sound quality']
# ['great speaker quality', 'dipper bass']
# ['bluetooth', 'feet range', 'portablility', 'sound quality', "'s louder", "n't enhance", "'s bit", 'slight vibration', 'full volume']
# []
# ['jbl']
# ['awesome', 'product ...', 'stars cz']
# ['nice', 'sound ...', 'got']
# ['sound', 'connectivity', 'jbl']
# []
# ['harman', 'sound system', 'luxurious cars']
# ['after30 min bettry', 'rong speaker m']
# ['red light', 'plz']
# ['video songs']
# ['sound', 'battery backup', 'less', 'amazon.com', 'battery details', 'technical terms..', 'allover', 'customer reviews']
# ['bought', 'connection drop issues', 'good base', 'sound', '% volume', 'great speaker', 'material', 'good quality']
# ['jbl', "n't compromise"]
# []
# ['clarity', 'thr jbl logo fades']
# ['sound quality', 'bluetooth', 'call', 'totally', 'supper product']
# ['worst']
# ['excellent']
# ['convenient', 'good decibel level', 'audio ...']
# ['perfect size']
# ['sound quality']
# ['good quality speakers', 'good volume', 'looks', 'fits', 'definitely', 'price range', 'takes', 'full charge', 'good time', 'perfect', 'travel partner', 'inbuilt mic', 'highly']
# ['j5', 'nice product good quality']
# ['build', 'sound', 'bass lover']
# []
# ['average sound']
# ['wow', 'colour 😍', 'quality product', "'m soooooo"]
# ['gud', 'sound quality', 'battery backup', 'product matchs']
# ['good sound quality']
# ['extreme quality', 'small size', 'excellent', 'highly', 'portable product']
# ['good backup']
# ["wo n't", 'croudy place', 'jbl', "'s speakers", 'bass', 'volume', 'loud speaker', 'perfect bass', 'reasonable price']
# ['bluetooth', 'nhi ho raha']
# ['ultimate', 'worth', "wo n't", 'bluetooth speaker', 'automatic shutdown problem', 'full sound w/o', 'vlc']
# ['fake', 'moment i']
# ['peoduct stopped working', 'red light continuiusly blinking since', 'days', 'done everything to restart/reboot but nothing happening']
# ['horrible', 'product ...', 'amazon', 'quality standards']
# ['bukwas']
# ['sound']
# ['unstable battery voltage volume', 'local market']
# ['bass', 'jbl']
# ['hour backup', 'sound quality']
# ['good sound..sound good', 'regular play time']
# ['zaap', 'portable speaker']
# ['compact', 'square ft room.best', 'indoor usage', 'worth']
# ['sound', 'good bass', "caller 's voice", "recipient 's", 'disappointed', 'brand name']
# ['received', 'return product']
# []
# []
# []
# []
# ['calls voice', 'clearly.for songs', 'battery']
# ['regular usage', 'jbl', 'good base', 'sound quality', 'small living room', 'bday party', 'minimum volume', 'high volume', 'cost wise', 'bit pricey ...', 'life ... ..']
# []
# []
# ['bought', 'july', 'may', 'service center', 'update', 'got', 'new logitech', 'bad time', 'jbl', 'interesting thing', 'logitech', "'s battery lasts", 'initial connectivity issues', 'linux', 'sound quality', 'mumbai', 'warranty']
# ['colour ...', 'similar colour cord']
# ['bluetooth']
# ['bluetooth', "n't work"]
# ['product', 'awesome', 'sound quality', 'sound clarity', 'packing', 'bass']
# []
# []
# ['nice', "qur'anic", 'loud voice', 'big room/hall']
# ['good product']
# ["'s purpose", 'seamless connectivity', 'love']
# ['sound quality']
# []
# ['worst', '... ... u cn nt use pendrive etc ... .whereas bluetooth cn', 'nd moreover bluetooth conectivety']
# ['experience', 'affordable price', '’ s', 'bluetooth', 'connects', 'laptop', 'mobile phone', 'sound', 'loudness', 'definitely', 'outdoor use', 'products', 'plug-in spot', 'overall']
# ['nice']
# ['crap', 'total crap']
# ['domestic use', 'laptop']
# ["i 'll", 'worth one👌👌👌👌👌']
# []
# []
# ['worth']
# ['battery', 'full volume']
# []
# ['worth buying', 'sound', 'please', 'tiny jbl', 'jbl speakers']
# []
# ['good sound quality', 'jbl', "'ll rate bass", 'overall', 'sound quality']
# ['nice', 'great balance', 'bass abd treble']
# ['trust online stuffs', 'amazing speaker', 'bluetooth', 'good investment', 'product ❤️']
# ['original price', 'buy']
# ['product quality', 'jbl']
# ['excellent amazing']
# ['nice product', 'light music']
# ['product image', 'amazon', 'actual product', 'never', 'jbl', 'future buyers']
# ['quality', 'god', 'home use']
# ['1st day', 'minutes i', 'perfect bass']
# ['usb slot', 'hence', "ca n't play", 'pen drive']
# ['poor']
# ['new product']
# ['blootooth', 'service center', 'aurangabad', 'amazon', 'check service center availability ...', 'defective ...']
# ['sound', 'worst', 'product ...', 'product anyhow', 'else']
# ['stopped']
# ['sound quality', 'jbl', 'regret buying']
# []
# ['good suffienct', 'room ... quality', 'decent doesnot', 'range ... ... battery life', 'good ... ... overall', 'product ... .if u r', 'price range']
# ['jbl', 'sound quality', 'call']
# ['battery']
# ['sufering', 'slide headache', 'bluetooth']
# ['return', 'pl', 'return policy', 'jbl']
# ['wonderful', 'real']
# []
# ['ok']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-a233bcf67401> in <module>()
#       7     jsonobj=response.json()
#       8     #print (jsonobj['number_negative_words'])
# ----> 9     emotion.append(jsonobj['Frequent Features'])
#      10     print (jsonobj['Frequent Features'])
#
# KeyError: 'Frequent Features'

# %%
import re  

import spacy

nlp = spacy.load('en_core_web_sm')

processed_tweets=[]

for tweet in range(0, len(emotion)):  
    processed_tweet = re.sub(r'\W', ' ', str(emotion[tweet]))

            
    # Remove all the special characters
    
    processed_tweet = re.sub(r'http\S+', ' ', processed_tweet)
    
    #processed_tweet = re.sub(r'https?:\/\/+', ' ', processed_tweet)
    
    #processed_tweet=re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', ' ',processed_tweet)
    
    processed_tweet=re.sub(r'www\S+', ' ', processed_tweet)
    
    processed_tweet=re.sub(r'co \S+', ' ', processed_tweet)
    # remove all single characters
    processed_tweet = re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_tweet)
 
    # Remove single characters from the start
    processed_tweet = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_tweet) 
 
    # Substituting multiple spaces with single space
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)
 
    # Removing prefixed 'b'
    processed_tweet = re.sub(r'^b\s+', ' ', processed_tweet)
    
    processed_tweet = re.sub(r'\d','',processed_tweet)
    
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)

 
    # Converting to Lowercase
    processed_tweet = processed_tweet.lower()
    
    processed_tweets.append(processed_tweet)
    
print (processed_tweets)
# Out:
# [' tiny speaker ', ' ca t work laptop ', ' defective product amazing excellent bass full volume upper model simply ', ' worst bluetooth ', ' bluetooth ', ' great fan worthful product ', ' plastic box package felt ', ' ', ' protable speaker ', ' ', ' portable speakers sound issue blue tooth switch long time pc ', ' review online certain frequencies good product ', ' awesome clear sound quality okayish max volume bluetooth connectivity build overall ', ' bluetooth portable speaker sound quality ', ' product quality good alternatives ', ' compitability returned ', ' nice blootooth speaker battery ', ' mic ', ' batter product ', ' great speaker go music perfect battery backup premium look ', ' dirty product battery life short nad t purchase ', ' w bluetooth speaker market it bluetooth connectivity stone connectivity fault piece sound quality sound clarity great weight jbl ', ' sound ', ' sound good ', ' bluetooth connection support good distance battery sound ', ' price point option ', ' speakr good bt speaker charger ', ' descent ', ' small portable speaker awesome bass ', ' really connects phone laptop bluetooth sec good quality ', ' jbl online market place harman serial number thanks amazon ', ' bluetooth speakers high output ma sony hifi speakers quality vocals little thing worth buyng ', ' awesome good bass ', ' ossum sound quality battery life good aur bhaai bahut achha hai chhote packet bada dhamaka hai ', ' good quality ', ' ', ' sound good nice bass battery long time sound non dust product noticeable problems ', ' ve ', ' pink black jbl ', ' love sound quality bluetooth ', ' truely aweaome product clear voice steardy body finishing nice put batt life long getz charge leas tym bingo jbl amazon quick ', ' sound ', ' fabulous short outings battery life happy results ', ' bluetooth mi price bt voice quality superb perfect bt jbl bahut bekaar hai badaaaaaaaaaaaa wala bekar mi bt samne bhus hai yai cheap voice toh usse jyda ', ' small device onboard radio ', ' sound good but it amazon customer there ', ' large rooms ideal hostel room bass cosidering somebody jbl pocket ', ' bluetooth order ', ' capacity battery ', ' chota packet bada dhamaka superb speaker couldn small speaker love ', ' ', ' good repent buying ', ' philips bluetooth speaker different brand basic requirement small size good descent output basic requirements ', ' eventually ', ' road trip truly wonderful experience continuous play pocket size speaker ', ' be bass missing with bluetooth cuts ', ' nice overall feature clarity speakers ', ' worst did ', ' product small rooms cars etc ', ' sound ', ' ', ' ofcrs comments compliments handy product luv wid nice color sound clarity perfect ', ' sound quality jbl guys boat philips lesser price ', ' ', ' ', ' sd card slot ', ' watt speaker ', ' jbl bluetooth speaker system success plz look ', ' average sound quality hours ', ' battery medium vol level sound quality good product ', ' perfect sound quality ', ' sound ', ' usb charger usb cable product didnt gud product ', ' where sound quality expected best value money budget product ', ' sound jbl brand t hesitate thank ', ' good ratings ca t audiophile grade tiny portable speaker frequency range jbl end making poor boom box primary purpose portable speakerphone noise cancelation conference calls jbl junk loud ', ' radio option usb sd card options ', ' bluetooth device worked pls product return ', ' loved compact size long wait sound quality jbl great work overall warranty card australia idk ', ' average ', ' good quality ', ' bluetooth good speaker ', ' prompt ', ' size ', ' great wireless bluetooth speakers performance xiaomi speakers ', ' bass upto expectation range k boat stone ', ' month bluetooth nt working response bakwaas mat kharido services center nahi hai ghata ', ' pros clear cons little bass shudders slight bass freqs voice ', ' impressive sound ouput keeping ', ' upto mark jbl ', ' buy happy sound nice ', ' music guy differentiate base jbl speaker ', ' small g ...

# %%
with open('az_absa_corpus.txt', 'w',encoding='utf-8') as f:
    for item in processed_tweets:
        f.write("%s\n" % item)

# %%
sample = open("az_absa_corpusF.txt", "r",encoding='utf-8') 
s = sample.read() 

# Replaces escape character with space 
f = s.replace("\n", " ")

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['good  product','good quality','good product','good  quality','good  product','quality'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
#stopwords.update(['good  product','good quality','good product','good  quality','good  product','quality'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fad3b50e5f8>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fad3b50e438>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality','good quality'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fd2718496a0>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality','good quality','good product'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fd27100deb8>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality','good quality','good product'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fd270638b00>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality','good quality','good product','battery life'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fd2705bd0f0>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality','good quality','good product','battery'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fd2705bbe48>

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#% matplotlib inline
stopwords= set(STOPWORDS)
stopwords.update(['quality','good quality','good product','battery'])
#stopwords.update(["status","still","must","support","",'pretty','mmine','loud','amazon','stays','anything','mine','month','proper','listen','written','box' ,"public","last","read","johnson","didn","ve","put","needs","save","help","deal","tories","years","articles","need","back","government","pm","back","life","care","everyone","give","day","country","new","look","mps","everything","really","need","hard","believe","even","still","re","eu","pic","dlidington", "philiphammonduk","jeremy_hunt","may","theresa_may","alanduncanmp","watson","work",'don', "anna_soubry","voted","heidi","constituents","heidiallen","claiming","yasmin","george_osborne","ayeshahazarika","tom","conservatives","griffith","hear","tory", "twitter","amberrudduk","love","take","real","friend","good","conservative","election","right","tell","vote","sure","parliament",'people',"justinegreening","tom_watson","labour","time","party","think","going","set","lines","nickymorgan","amberruddhr","will","one","brexit","say","mp","said","want","come","well","no","see","now","know","borisjohnson","stephentwigg","please","happy","share","remember","thank","much","constituent","spaces","job","action","got","jbl",'sound','product','speaker','rha','gya','high','hai',"today",'ho','go','ll','amazes','working','thing','laptop','gaya','raha','purchase','bluetooth','speakers','amazing','compactness','connect'])

wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=150, width=1000, height=450,
                          random_state=42
                         ).generate(f)
print(wordcloud)
plt.figure(figsize = (10, 10), facecolor = None) 
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.tight_layout(pad=0)

plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=2500)
#plt.savefig('wordcloud.png', facecolor='k', bbox_inches=tight')'
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f5daf3507f0>

# %%
df_m['Label']=emotion
df_m.to_csv('az_absa.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m=pd.read_csv('amazon_reviews.csv')
#df_m1= df_m.sample(frac = 0.10)
df_m

# %%
import requests
x=df_m['content']
no_neg=[]
no_pos=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/article_stats/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    if response.status_code==200:
      #print (jsonobj['number_negative_words'])
      no_neg.append(jsonobj['number_negative_words'])
      print (jsonobj['number_positive_words'])
      no_pos.append(jsonobj['number_positive_words'])
    else:     

      no_neg.append(0)
      #print (jsonobj['number_of_words'])
      no_pos.append(0)

# %%
len (no_pos)

# %%
len (no_neg)

# %%
df_m['negativewords']=no_neg
df_m['positivewords']=no_pos
df_m

# %%
df_m.to_csv('amazon_reviews_annotated_negpos.csv')

# %%
df_m['month']=df_m['date'].astype(float).apply(lambda x :x[6:8])
df_m

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m2=pd.read_csv('wp2words.csv')

# %%
import requests
x=df_m2['text']
prob=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/api/hate/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    prob.append(jsonobj['probability'])
    print (jsonobj['probability'])

# %%
import pandas as pd
import numpy as np

# Read in the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('wp2words.csv')

print (f"Shape of dataframe is {df.shape}")
df.head()

# %%
X=df['text']
Z=df['text']
print (Z)

# %%
import requests

arr=[]
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    arr.append(jsonobj[0]['Stance'])
    print (jsonobj[0]['Stance'])

url="http://104.248.174.180/api/stance/brexit_tweets/"

for i in X:
    post_json(url,{"Tweets":[i]})

# %%
df['stance']=arr
df

# %%
len(arr)

# %%
df.to_csv("wp2pro.csv")

# %%
import pandas as pd
import numpy as np

# Read in the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1=pd.read_csv('#antibrexit_tweets.csv')


print (f"Shape of dataframe is {df1.shape}")
df1.head()
X=df1['text']
Z=df1['text']


print (Z)

# %%
import requests

arr1=[]
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    arr1.append(jsonobj[0]['Stance'])
    print (jsonobj[0]['Stance'])

url="http://104.248.174.180/api/stance/brexit_tweets/"

for i in X:
    post_json(url,{"Tweets":[i]})

# %%
len(arr1)

# %%
df1['stance']=arr1
df1

# %%
df1.to_csv("wp2anti.csv")

# %%
df

# %%
df.shape

# %%
df1.shape

# %%
df.head()

# %%
df1.head()

# %%
del df['positivewords']

# %%
df

# %%
del df1['Unnamed: 0']

# %%
df1

# %%
df1.to_csv("wp2anti_up1.csv")

# %%
df.to_csv("wp2pro_up.csv")

# %%
import pandas as pd

a = pd.read_csv("wp2anti_up.csv")
b = pd.read_csv("wp2pro_up.csv")
merged = a.merge(b)
merged.to_csv("output.csv", index=False)

# %%
ddf=pd.read_csv("output.csv")
ddf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m2=pd.read_csv('wp2words.csv')

import requests
#send_response(code, message=None) 
x=df_m2['text']
prob=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/api/hate/?query={i}')
    print(response.json())
    jsonobj=response.json()
    #prob.append(jsonobj['probability'])
    #print (jsonobj['probability'])

# %%
import requests
x=df_m['content']
emotion=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/api/emotion/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    #print (jsonobj['number_negative_words'])
    emotion.append(jsonobj['Label'])
    print (jsonobj['Label'])

# %%
df_m['Label']=emotion
df_m.to_csv('az_emotion.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m=pd.read_csv('amazon_reviews.csv')
#df_m1= df_m.sample(frac = 0.10)
df_m

# %%
import requests
x=df_m['content']
no_neg=[]
no_pos=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/article_stats/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    if response.status_code==200:
      #print (jsonobj['number_negative_words'])
      no_neg.append(jsonobj['number_negative_words'])
      print (jsonobj['number_positive_words'])
      no_pos.append(jsonobj['number_positive_words'])
    else:     

      no_neg.append(0)
      #print (jsonobj['number_of_words'])
      no_pos.append(0)

# %%
len (no_pos)

# %%
len (no_neg)

# %%
df_m['negativewords']=no_neg
df_m['positivewords']=no_pos
df_m

# %%
df_m.to_csv('amazon_reviews_annotated_negpos.csv')

# %%
df_m['month']=df_m['date'].astype(float).apply(lambda x :x[6:8])
df_m

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m2=pd.read_csv('wp2words.csv')

# %%
import requests
x=df_m2['text']
prob=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/api/hate/?query={i}')
    #print(response.json())
    jsonobj=response.json()
    prob.append(jsonobj['probability'])
    print (jsonobj['probability'])

# %%
import pandas as pd
import numpy as np

# Read in the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('wp2words.csv')

print (f"Shape of dataframe is {df.shape}")
df.head()

# %%
X=df['text']
Z=df['text']
print (Z)

# %%
import requests

arr=[]
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    arr.append(jsonobj[0]['Stance'])
    print (jsonobj[0]['Stance'])

url="http://104.248.174.180/api/stance/brexit_tweets/"

for i in X:
    post_json(url,{"Tweets":[i]})

# %%
df['stance']=arr
df

# %%
len(arr)

# %%
df.to_csv("wp2pro.csv")

# %%
import pandas as pd
import numpy as np

# Read in the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1=pd.read_csv('#antibrexit_tweets.csv')


print (f"Shape of dataframe is {df1.shape}")
df1.head()
X=df1['text']
Z=df1['text']


print (Z)

# %%
import requests

arr1=[]
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    arr1.append(jsonobj[0]['Stance'])
    print (jsonobj[0]['Stance'])

url="http://104.248.174.180/api/stance/brexit_tweets/"

for i in X:
    post_json(url,{"Tweets":[i]})

# %%
len(arr1)

# %%
df1['stance']=arr1
df1

# %%
df1.to_csv("wp2anti.csv")

# %%
df

# %%
df.shape

# %%
df1.shape

# %%
df.head()

# %%
df1.head()

# %%
del df['positivewords']

# %%
df

# %%
del df1['Unnamed: 0']

# %%
df1

# %%
df1.to_csv("wp2anti_up1.csv")

# %%
df.to_csv("wp2pro_up.csv")

# %%
import pandas as pd

a = pd.read_csv("wp2anti_up.csv")
b = pd.read_csv("wp2pro_up.csv")
merged = a.merge(b)
merged.to_csv("output.csv", index=False)

# %%
ddf=pd.read_csv("output.csv")
ddf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_m2=pd.read_csv('wp2words.csv')

import requests
#send_response(code, message=None) 
x=df_m2['text']
prob=[]
for i in x:
    response=requests.get(f'http://104.248.174.180/api/hate/?query={i}')
    print(response.json())
    jsonobj=response.json()
    #prob.append(jsonobj['probability'])
    #print (jsonobj['probability'])
