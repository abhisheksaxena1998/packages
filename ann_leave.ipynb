# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksaxena1998/packages/blob/master/ann_leave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
stance=[]
x="Brexit is a disaster"
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    print (jsonobj[0]['Stance'])

url="http://104.248.174.180/api/stance/brexit_tweets/"

post_json(url,{"Tweets":[x]})
# Out:
# stay

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('tomwatson.csv')
df
# Out:
#            date        name                                              tweet
# 0    2019-11-20  Tom Watson       Blimey. I’ve never seen that. Was that 2015?
# 1    2019-11-20  Tom Watson  Impressive news that @UK_Music has now reveale...
# 2    2019-11-19  Tom Watson  well, yes, I guess you're right Audrey.  The d...
# 3    2019-11-19  Tom Watson  I consider the @Ouraring to be the most powerf...
# 4    2019-11-17  Tom Watson  Three fabulous days of learning to be a Level ...
# ..          ...         ...                                                ...
# 557  2019-06-02  Tom Watson  This week @_UKCoaching celebrates the inspirin...
# 558  2019-06-02  Tom Watson  700 football pitches lost since 2010 is a disg...
# 559  2019-06-01  Tom Watson  As I look at the list of candidates who served...
# 560  2019-06-01  Tom Watson  Unforgivable. https://www.theguardian.com/poli...
# 561  2019-06-01  Tom Watson  And me Bill. https://twitter.com/billybragg/st...
#
# [562 rows x 3 columns]

# %%
stance=[]
for i in df['tweet']:
    def post_json(url,json_data):

      res= requests.post(url,json=json_data)
      #print (res.json())
      jsonobj=res.json()
      stance.append(jsonobj[0]['Stance'])
      print (jsonobj[0]['Stance'])
    post_json(url,{"Tweets":[i]})
# Out:
# no sentiment
# leave
# no sentiment
# leave
# irrelevant
# stay
# irrelevant
# stay
# stay
# irrelevant
# leave
# irrelevant
# no sentiment
# no sentiment
# leave
# leave
# leave
# irrelevant
# leave
# leave
# leave
# leave
# leave
# irrelevant
# leave
# irrelevant
# leave
# leave
# leave
# leave
# irrelevant
# no sentiment
# irrelevant
# leave
# irrelevant
# leave
# leave
# leave
# leave
# leave
# irrelevant
# irrelevant
# leave
# irrelevant
# leave
# leave
# leave
# irrelevant
# leave
# leave
# stay
# irrelevant
# leave
# leave
# no sentiment
# leave
# no sentiment
# irrelevant
# irrelevant
# leave
# leave
# leave
# leave
# leave
# leave
# stay
# leave
# no sentiment
# leave
# no sentiment
# leave
# irrelevant
# irrelevant
# no sentiment
# leave
# leave
# leave
# leave
# irrelevant
# leave
# leave
# stay
# irrelevant
# irrelevant
# leave
# leave
# leave
# leave
# irrelevant
# leave
# leave
# irrelevant
# stay
# leave
# leave
# leave
# leave
# leave
# leave
# irrelevant
# stay
# irrelevant
# leave
# irrelevant
# leave
# stay
# stay
# leave
# stay
# stay
# no sentiment
# irrelevant
# stay
# irrelevant
# stay
# leave
# leave
# irrelevant
# leave
# leave
# leave
# leave
# stay
# stay
# no sentiment
# irrelevant
# irrelevant
# leave
# leave
# irrelevant
# irrelevant
# leave
# leave
# irrelevant
# stay
# leave
# irrelevant
# stay
# irrelevant
# stay
# stay
# no sentiment
# leave
# irrelevant
# leave
# leave
# stay
# leave
# leave
# irrelevant
# no sentiment
# irrelevant
# leave
# irrelevant
# stay
# leave
# stay
# irrelevant
# irrelevant
# leave
# irrelevant
# leave
# stay
# no sentiment
# leave
# leave
# stay
# leave
# leave
# leave
# leave
# leave
# no sentiment
# leave
# leave
# leave
# stay
# stay
# leave
# leave
# leave
# leave
# leave
# leave
# leave
# leave
# stay
# leave
# irrelevant
# stay
# stay
# leave
# leave
# leave
# leave
# irrelevant
# leave
# irrelevant
# irrelevant
# irrelevant
# leave
# leave
# irrelevant
# leave
# stay
# no sentiment
# irrelevant
# stay
# stay
# leave
# stay
# stay
# leave
# leave
# leave
# irrelevant
# irrelevant
# irrelevant
# leave
# leave
# leave
# irrelevant
# irrelevant
# leave
# leave
# irrelevant
# leave
# stay
# leave
# irrelevant
# leave
# no sentiment
# leave
# leave
# stay
# leave
# leave
# leave
# irrelevant
# irrelevant
# leave
# no sentiment
# stay
# irrelevant
# stay
# irrelevant
# no sentiment
# leave
# no sentiment
# irrelevant
# irrelevant
# stay
# leave
# leave
# leave
# irrelevant
# irrelevant
# leave
# leave
# irrelevant
# leave
# leave
# leave
# leave
# leave
# leave
# stay
# leave
# irrelevant
# irrelevant
# stay
# stay
# irrelevant
# stay
# leave
# leave
# no sentiment
# leave
# irrelevant
# leave
# irrelevant
# stay
# leave
# leave
# irrelevant
# leave
# no sentiment
# stay
# stay
# leave
# leave
# no sentiment
# leave
# stay
# no sentiment
# irrelevant
# leave
# leave
# leave
# irrelevant
# irrelevant
# leave
# leave
# irrelevant
# no sentiment
# leave
# leave
# leave
# irrelevant
# leave
# leave
# irrelevant
# irrelevant
# irrelevant
# leave
# stay
# leave
# leave
# stay
# stay
# no sentiment
# stay
# no sentiment
# leave
# leave
# leave
# leave
# leave
# no sentiment
# leave
# leave
# leave
# leave
# irrelevant
# no sentiment
# no sentiment
# irrelevant
# irrelevant
# leave
# irrelevant
# no sentiment
# leave
# leave
# leave
# stay
# leave
# leave
# irrelevant
# leave
# no sentiment
# irrelevant
# no sentiment
# stay
# stay
# leave
# leave
# leave
# leave
# leave
# irrelevant
# leave
# leave
# irrelevant
# irrelevant
# irrelevant
# leave
# leave
# leave
# irrelevant
# leave
# leave
# leave
# irrelevant
# irrelevant
# stay
# stay
# stay
# irrelevant
# leave
# leave
# leave
# leave
# leave
# irrelevant
# stay
# no sentiment
# leave
# leave
# leave
# leave
# leave
# leave
# irrelevant
# no sentiment
# irrelevant
# leave
# leave
# irrelevant
# stay
# no sentiment
# leave
# leave
# irrelevant
# leave
# leave
# leave
# leave
# leave
# stay
# stay
# leave
# irrelevant
# leave
# leave
# stay
# leave
# leave
# leave
# irrelevant
# leave
# leave
# no sentiment
# irrelevant
# irrelevant
# stay
# stay
# irrelevant
# stay
# stay
# irrelevant
# irrelevant
# leave
# stay
# irrelevant
# no sentiment
# irrelevant
# irrelevant
# stay
# leave
# no sentiment
# irrelevant
# stay
# stay
# irrelevant
# irrelevant
# irrelevant
# stay
# no sentiment
# no sentiment
# leave
# leave
# leave
# leave
# leave
# irrelevant
# leave
# irrelevant
# irrelevant
# leave
# stay
# no sentiment
# irrelevant
# stay
# leave
# leave
# leave
# irrelevant
# leave
# leave
# leave
# leave
# stay
# leave
# leave
# no sentiment
# leave
# leave
# leave
# leave
# leave
# irrelevant
# no sentiment
# no sentiment
# stay
# stay
# leave
# leave
# leave
# leave
# leave
# no sentiment
# leave
# leave
# irrelevant
# irrelevant
# stay
# leave
# no sentiment
# irrelevant
# no sentiment
# no sentiment
# no sentiment
# leave
# leave
# no sentiment
# leave
# leave
# leave
# stay
# leave
# leave
# leave
# leave
# irrelevant
# irrelevant
# leave
# no sentiment
# leave
# irrelevant
# leave
# leave
# leave
# leave
# leave
# stay
# irrelevant
# leave
# no sentiment
# leave
# leave
# irrelevant
# leave
# leave
# stay
# leave
# no sentiment
# leave
# leave
# leave
# leave
# stay
# irrelevant
# no sentiment
# no sentiment
# stay
# leave
# no sentiment
# stay
# stay
# leave
# leave
# leave
# irrelevant
# stay
# irrelevant
# leave
# no sentiment
# leave
# irrelevant
# leave
# irrelevant
# stay

# %%
df['date']=df['date'].apply(lambda x :x[5:7])
df['stance']=stance

df.to_csv('tomwatson_stance.csv')

# %%
df=pd.read_csv('tomwatson_stance.csv')
df
# Out:
#      Unnamed: 0  ...        stance
# 0             0  ...  no sentiment
# 1             1  ...         leave
# 2             2  ...  no sentiment
# 3             3  ...         leave
# 4             4  ...    irrelevant
# ..          ...  ...           ...
# 557         557  ...         leave
# 558         558  ...    irrelevant
# 559         559  ...         leave
# 560         560  ...    irrelevant
# 561         561  ...          stay
#
# [562 rows x 5 columns]
