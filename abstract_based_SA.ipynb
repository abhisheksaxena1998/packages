# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksaxena1998/packages/blob/master/abstract_based_SA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
stance=[]
x="Brexit is a disaster"
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    print (jsonobj['Polarity'])
    


url=f"http://104.248.174.180/api/absa/?query={x}"

post_json(url,{"Tweets":[x]})
# Out:
# 0.0

# %%
import requests
stance=[]
x="Brexit is a disaster"
polarity=[]
threshold=[]
frequent_features=[]
absa=[]
def post_json(url,json_data):
    res= requests.post(url,json=json_data)
    #print (res.json())
    jsonobj=res.json()
    print (jsonobj['Polarity'])
    polarity.append(jsonobj['Polarity'])
    print (jsonobj['Threshold'])
    threshold.append(jsonobj['Threshold'])
    print (jsonobj['Frequent Features'])
    frequent_features.append(jsonobj['Frequent Features'])
    print (jsonobj['ABSA Scores'])
    absa.append(jsonobj['ABSA Scores'])

    


    url=f"http://104.248.174.180/api/absa/?query={x}"
post_json(url,{"Tweets":[x]})
# Out:
# 0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests


df=pd.read_csv('output.csv',encoding='latin1')
X=df['text']
polarity=[]
threshold=[]
frequent_features=[]
absa=[]
for i in X:
        res=requests.get(f"http://104.248.174.180/api/absa/?query={i}")
        #print (res.json())
        jsonobj=res.json()
        print (jsonobj['Polarity'])
        polarity.append(jsonobj['Polarity'])
        print (jsonobj['Threshold'])
        threshold.append(jsonobj['Threshold'])
        print (jsonobj['Frequent Features'])
        frequent_features.append(jsonobj['Frequent Features'])
        print (jsonobj['ABSA Scores'])
        absa.append(jsonobj['ABSA Scores'])
# Out:
# -0.05
# 0.01
# ['james ii']
# [{'james ii': [-0.05], 'sentence': ['i wonder how long james ii fans carried on objecting to the.']}]
# 0.0
# 0.0
# []
# []
# 0.05625
# 0.04
# ['eu', 'vat']
# [{'eu': [0.0, 0.08333333333333333], 'sentence': ['when we leave the eu.', 'we will also not have to pay extras for bailing out other eu failed states nor will we have to pay any vat or be taxed further for being more successful than other eu states.']}, {'vat': [0.08333333333333333], 'sentence': ['we will also not have to pay extras for bailing out other eu failed states nor will we have to pay any vat or be taxed further for being more successful than other eu states.']}]
# 0.0
# 0.0
# []
# []
# 0.5
# 0.05
# ['police officers', 'streets safer', 'safe place', 'well', 'borisjohnson']
# ...

# %%
df['polarity']=polarity
df['threshold']=threshold
df['frequent_features']=frequent_features
df['absa']=absa

# %%
df.to_csv('absa_Output.csv')

# %%
df1=pd.read_csv('absa_Output.csv')
df1
# Out:
#       Unnamed: 0  ...                                               absa
# 0              0  ...  [{'james ii': [-0.05], 'sentence': ['i wonder ...
# 1              1  ...                                                 []
# 2              2  ...  [{'eu': [0.0, 0.08333333333333333], 'sentence'...
# 3              3  ...                                                 []
# 4              4  ...  [{'police officers': [0.5], 'sentence': ['we a...
# ...          ...  ...                                                ...
# 3378        3378  ...  [{'protesters': [0.0], 'sentence': ['protester...
# 3379        3379  ...                                                 []
# 3380        3380  ...  [{'het onderzoek speelt natuurlijk weer op emo...
# 3381        3381  ...  [{'//www.washingtonpost.com/entertainment/book...
# 3382        3382  ...  [{'idiotic @': [0.16666666666666669], 'sentenc...
#
# [3383 rows x 23 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('#Leave_tweets.csv')
df
# Out:
#        Unnamed: 0  ...                                               html
# 0               0  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 1               1  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 2               2  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 3               3  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 4               4  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# ...           ...  ...                                                ...
# 20322       20322  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20323       20323  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20324       20324  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20325       20325  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20326       20326  ...  <p class="TweetTextSize js-tweet-text tweet-te...
#
# [20327 rows x 17 columns]

# %%
stance=[]
for i in df['text']:
    def post_json(url,json_data):
      global count

      res= requests.post(url,json=json_data)
      #print (res.json())
      jsonobj=res.json()
      stance.append(jsonobj[0]['Stance'])
      count+=1
      print (jsonobj[0]['Stance'])
      print (count)
    post_json(url,{"Tweets":[i]})
# Out:
# leave
# 1
# leave
# 2
# leave
# 3
# irrelevant
# 4
# leave
# 5
# leave
# 6
# stay
# 7
# leave
# 8
# leave
# 9
# leave
# 10
# leave
# 11
# leave
# 12
# irrelevant
# 13
# leave
# 14
# leave
# 15
# leave
# 16
# leave
# 17
# stay
# 18
# leave
# 19
# leave
# 20
# leave
# 21
# leave
# 22
# leave
# 23
# irrelevant
# 24
# leave
# 25
# leave
# 26
# stay
# 27
# leave
# 28
# leave
# 29
# leave
# 30
# leave
# 31
# leave
# 32
# irrelevant
# 33
# leave
# 34
# leave
# 35
# leave
# 36
# leave
# 37
# stay
# 38
# leave
# 39
# leave
# 40
# leave
# 41
# leave
# 42
# leave
# 43
# no sentiment
# 44
# stay
# 45
# stay
# 46
# stay
# 47
# leave
# 48
# leave
# 49
# leave
# 50
# no sentiment
# 51
# leave
# 52
# irrelevant
# 53
# leave
# 54
# leave
# 55
# leave
# 56
# leave
# 57
# leave
# 58
# leave
# 59
# leave
# 60
# leave
# 61
# leave
# 62
# leave
# 63
# leave
# 64
# leave
# 65
# leave
# 66
# leave
# 67
# leave
# 68
# leave
# 69
# stay
# 70
# leave
# 71
# leave
# 72
# no sentiment
# 73
# leave
# 74
# leave
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('#Leave_tweets.csv')
df
# Out:
#        Unnamed: 0  ...                                               html
# 0               0  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 1               1  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 2               2  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 3               3  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 4               4  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# ...           ...  ...                                                ...
# 20322       20322  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20323       20323  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20324       20324  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20325       20325  ...  <p class="TweetTextSize js-tweet-text tweet-te...
# 20326       20326  ...  <p class="TweetTextSize js-tweet-text tweet-te...
#
# [20327 rows x 17 columns]

# %%
stance=[]
for i in df['text']:
    def post_json(url,json_data):
      global count

      res= requests.post(url,json=json_data)
      #print (res.json())
      jsonobj=res.json()
      stance.append(jsonobj[0]['Stance'])
      count+=1
      print (jsonobj[0]['Stance'])
      print (count)
    post_json(url,{"Tweets":[i]})
# Out:
# leave
# 1
# leave
# 2
# leave
# 3
# irrelevant
# 4
# leave
# 5
# leave
# 6
# stay
# 7
# leave
# 8
# leave
# 9
# leave
# 10
# leave
# 11
# leave
# 12
# irrelevant
# 13
# leave
# 14
# leave
# 15
# leave
# 16
# leave
# 17
# stay
# 18
# leave
# 19
# leave
# 20
# leave
# 21
# leave
# 22
# leave
# 23
# irrelevant
# 24
# leave
# 25
# leave
# 26
# stay
# 27
# leave
# 28
# leave
# 29
# leave
# 30
# leave
# 31
# leave
# 32
# irrelevant
# 33
# leave
# 34
# leave
# 35
# leave
# 36
# leave
# 37
# stay
# 38
# leave
# 39
# leave
# 40
# leave
# 41
# leave
# 42
# leave
# 43
# no sentiment
# 44
# stay
# 45
# stay
# 46
# stay
# 47
# leave
# 48
# leave
# 49
# leave
# 50
# no sentiment
# 51
# leave
# 52
# irrelevant
# 53
# leave
# 54
# leave
# 55
# leave
# 56
# leave
# 57
# leave
# 58
# leave
# 59
# leave
# 60
# leave
# 61
# leave
# 62
# leave
# 63
# leave
# 64
# leave
# 65
# leave
# 66
# leave
# 67
# leave
# 68
# leave
# 69
# stay
# 70
# leave
# 71
# leave
# 72
# no sentiment
# 73
# leave
# 74
# leave
# ...
